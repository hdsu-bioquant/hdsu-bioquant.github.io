# %%
pip install scvi-colab
# Out:
# ...
#      |████████████████████████████████| 240 kB 7.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 87 kB 50.0 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 123.9 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scvi_colab import install

# %%
install(run_outside_colab=True)
# Out:
# INFO     scvi-colab: Installing scvi-tools.
# INFO     scvi-colab: Install successful. Testing import.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 install(run_outside_colab=True)
#
# File ~/miniconda/lib/python3.9/site-packages/scvi_colab/_core.py:82, in install(version, branch, run_outside_colab, unfixed)
#      79 logger.info("Install successful. Testing import.")
#      81 try:
# ---> 82     import scvi  # noqa: F401
#      83 except ContextualVersionConflict:
#      84     logger.warning(
#      85         "Import unsuccessful. Try restarting (not resetting) the session and running again."
#      86     )
#
# File ~/miniconda/lib/python3.9/site-packages/scvi/__init__.py:8
#       5 import warnings
#       7 from ._constants import METRIC_KEYS, REGISTRY_KEYS
# ----> 8 from ._settings import settings
# ...
